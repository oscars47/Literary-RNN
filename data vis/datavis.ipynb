# %% [markdown]
# # Visualizing results for TP experiment

# %% [markdown]
# ### Oscar Scholin

# %%
# imports
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Read in Data, clean csv

# %%
# read in csv
data_raw = pd.read_csv('survey_12_25.csv')
data_raw
# Out:
#    Age                                             1react  \
# 0   21         A little confused, pictures a heroic scene
# 1   20  This conjures images of the Vikings, or of a l...
# 2   54  The initial word "lamderg" uncapitalized immed...
# 3   21  Fancy writing, lack of capitalization a bit ha...
# 4   22  Semantically, I felt a rhythm of ascent. There...
# 5   20  It reads like an old English or Norse myth tra...
# 6   19  It seems like poetry that I read in my senior ...
# 7   21   Momentous, lots of gravitas. Movement, tension.
# 8   61  are you making a statement using no caps and f...
#
#                                             1details  \
# 0  unsure what his buckler is, why did he a roll ...
# 1  I am confused by the last sentence—I feel like...
# 2  initial uncapitalization of the first word wit...
# 3  Definitely the number of metaphors are cool. I...
# 4  The disconnections between the sentences appea...
# 5  Some of the figurative language seems stilted,...
# 6  A couple words/names that I don't recognize / ...
# 7  Tenses change as the piece progresses, grammar...
# 8  the first part speaks of a character -- fine -...
#
#                                            1creative  \
# 0  Good: there are numerous interesting ideas and...
# 1  Good: there are numerous interesting ideas and...
# 2  Good: there are numerous interesting ideas and...
# 3  Good: there are numerous interesting ideas and...
# 4  Good: there are numerous interesting ideas and...
# 5  Good: there are numerous interesting ideas and...
# 6  Adequate: there are some interesting ideas and...
# 7  Good: there are numerous interesting ideas and...
# 8  Adequate: there are some interesting ideas and...
#
#                                         1creajustify  \
# 0                                                NaN
# 1  Nature imagery is strong, but doesn’t seem par...
# 2  usually, the punctuation is at the end of a li...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  creates an interesting image, but don't think ...
# 7                                                NaN
# 8  good on the visuals, but the storyline lacks c...
#
#                                            1cohesive  1cohjustify  \
# 0  Adequate: I could follow to the end, but in nu...          NaN
# 1  Good: I was able to mostly follow from beginni...          NaN
# 2  Good: I was able to mostly follow from beginni...          NaN
# 3  Adequate: I could follow to the end, but in nu...          NaN
# 4  Adequate: I could follow to the end, but in nu...          NaN
# 5  Adequate: I could follow to the end, but in nu...          NaN
# 6  Adequate: I could follow to the end, but in nu...          NaN
# 7  Good: I was able to mostly follow from beginni...          NaN
# 8  Adequate: I could follow to the end, but in nu...          NaN
#
#                                          1compelling  \
# 0  Adequate: That was somewhat enjoyable! Next, p...
# 1  Good: Wow, that was a very intriguing excerpt!...
# 2  Adequate: That was somewhat enjoyable! Next, p...
# 3  Good: Wow, that was a very intriguing excerpt!...
# 4  Good: Wow, that was a very intriguing excerpt!...
# 5  Adequate: That was somewhat enjoyable! Next, p...
# 6  Fair: So... I read it, but can we just move on...
# 7  Good: Wow, that was a very intriguing excerpt!...
# 8  Fair: So... I read it, but can we just move on...
#
#                                          1comjustify  \
# 0                                                NaN
# 1  I have some remaining points of confusion, and...
# 2  If you told me a human wrote it, I would want ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  I'm a bit confused -- could have used more con...
#
#                                               2react  ...  \
# 0  barely comprehensible but i feel a sense of wo...  ...
# 1  This seems artsy but I feel confused. I am not...  ...
# 2  I take issue with NO capitalizations. Moving b...  ...
# 3  I like this excerpt a lot more, much more poet...  ...
# 4                          I am thoroughly confused.  ...
# 5  Confusion. First “paragraph” reads like litera...  ...
# 6  Similar to the last one—mostly, I'm stuck on t...  ...
# 7  Light and graceful, medieval, also momentous. ...  ...
# 8  nonsensical - and spelling errors - is that in...  ...
#
#                                          3compelling  \
# 0  Good: Wow, that was a very intriguing excerpt!...
# 1  Adequate: That was somewhat enjoyable! Next, p...
# 2  Good: Wow, that was a very intriguing excerpt!...
# 3  Good: Wow, that was a very intriguing excerpt!...
# 4  Adequate: That was somewhat enjoyable! Next, p...
# 5       Exceptional: OMG where can I find the rest??
# 6  Adequate: That was somewhat enjoyable! Next, p...
# 7  Fair: So... I read it, but can we just move on...
# 8  Fair: So... I read it, but can we just move on...
#
#                                          3comjustify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  then again, it might be like Pollack before hi...
#
#                                               4react  \
# 0  confused, seems to have some romantic underton...
# 1  This gives the sense that it is a fairytale or...
# 2  The key word I locked in to was the word "bear...
# 3  Not getting much feeling in this one as I don’...
# 4  I think every couple of sentences makes sense,...
# 5                                Wistful, nostalgic
# 6  I think it started in a way that made more sen...
# 7  Spiritual, commune with nature, mystic signifi...
# 8  reads like a code of some kind -- tough to follow
#
#                                             4details  \
# 0  unsure if paintence, painsess, mosser are typo...
# 1  I am confused by some of the language. Perhaps...
# 2                          sangaline.....mosser...\n
# 3  This is the least cohesive piece out of all th...
# 4  I am puzzled by how the first sentence connect...
# 5                  A lot of made-up words. Painsess?
# 6           No periods/capitals, some older language
# 7  Bad construction. Bad grammar, vocabulary that...
# 8       I found most of it totally confusing, sorry.
#
#                                            4creative  \
# 0  Adequate: there are some interesting ideas and...
# 1  Adequate: there are some interesting ideas and...
# 2  Good: there are numerous interesting ideas and...
# 3  Adequate: there are some interesting ideas and...
# 4  Adequate: there are some interesting ideas and...
# 5  Adequate: there are some interesting ideas and...
# 6  Adequate: there are some interesting ideas and...
# 7  Fair: there are a few places that might spark ...
# 8  Fair: there are a few places that might spark ...
#
#                                         4creajustify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  The beginning drew me in, but I got lost by th...
# 7                                                NaN
# 8                  I have no idea what this is about
#
#                                            4cohesive  \
# 0  Adequate: I could follow to the end, but in nu...
# 1  Adequate: I could follow to the end, but in nu...
# 2  Adequate: I could follow to the end, but in nu...
# 3  Poor: words? sure, something like that may hav...
# 4  Fair:  I made it to the end, but barely. Could...
# 5  Adequate: I could follow to the end, but in nu...
# 6  Adequate: I could follow to the end, but in nu...
# 7  Fair:  I made it to the end, but barely. Could...
# 8  Fair:  I made it to the end, but barely. Could...
#
#                                          4cohjustify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  That is, assuming the intent was poetry and no...
# 6                                                NaN
# 7                                                NaN
# 8                                  seems very random
#
#                                          4compelling          4comjustify
# 0  Adequate: That was somewhat enjoyable! Next, p...                  NaN
# 1  Adequate: That was somewhat enjoyable! Next, p...                  NaN
# 2  Good: Wow, that was a very intriguing excerpt!...                  NaN
# 3  Fair: So... I read it, but can we just move on...                  NaN
# 4  Adequate: That was somewhat enjoyable! Next, p...                  NaN
# 5  Adequate: That was somewhat enjoyable! Next, p...                  NaN
# 6  Fair: So... I read it, but can we just move on...                  NaN
# 7                Poor: I literally couldn't read it.                  NaN
# 8  Fair: So... I read it, but can we just move on...  no further comments
#
# [9 rows x 33 columns]

# %%
# print out columns
data_raw.columns
# Out:
# Index(['Age', '1react', '1details', '1creative', '1creajustify', '1cohesive',
#        '1cohjustify', '1compelling', '1comjustify', '2react', '2details',
#        '2creative', '2creajustify', '2cohesive', '2cohjustify', '2compelling',
#        '2comjustify', '3react', '3details', '3creative', '3creajustify',
#        '3cohesive', '3cohjustify', '3compelling', '3comjustify', '4react',
#        '4details', '4creative', '4creajustify', '4cohesive', '4cohjustify',
#        '4compelling', '4comjustify'],
#       dtype='object')

# %%
# initialize clean df
data_clean = pd.DataFrame()
# list of possible ratings
ratings_key = ['Poor', 'Fair', 'Adequate', 'Good', 'Exceptional']
creative1=[]
creative2=[]
creative3=[]
creative4=[]
cohesive1=[]
cohesive2=[]
cohesive3=[]
cohesive4=[]
compelling1=[]
compelling2=[]
compelling3=[]
compelling4=[]
for i in range(len(data_raw)): # for every reviewer
    # go through every object
    
    creative1.append(ratings_key.index(data_raw['1creative'][i].split(':')[0]))
    cohesive1.append(ratings_key.index(data_raw['1cohesive'][i].split(':')[0]))
    compelling1.append(ratings_key.index(data_raw['1compelling'][i].split(':')[0]))

    creative2.append(ratings_key.index(data_raw['2creative'][i].split(':')[0]))
    cohesive2.append(ratings_key.index(data_raw['2cohesive'][i].split(':')[0]))
    compelling2.append(ratings_key.index(data_raw['2compelling'][i].split(':')[0]))

    creative3.append(ratings_key.index(data_raw['3creative'][i].split(':')[0]))
    cohesive3.append(ratings_key.index(data_raw['3cohesive'][i].split(':')[0]))
    compelling3.append(ratings_key.index(data_raw['3compelling'][i].split(':')[0]))

    creative4.append(ratings_key.index(data_raw['4creative'][i].split(':')[0]))
    cohesive4.append(ratings_key.index(data_raw['4cohesive'][i].split(':')[0]))
    compelling4.append(ratings_key.index(data_raw['4compelling'][i].split(':')[0]))

data_clean['Age'] = data_raw['Age']
data_clean['Creative1'] = creative1
data_clean['Creative2'] = creative2
data_clean['Creative3'] = creative3
data_clean['Creative4'] = creative4
data_clean['Cohesive1'] = cohesive1
data_clean['Cohesive2'] = cohesive2
data_clean['Cohesive3'] = cohesive3
data_clean['Cohesive4'] = cohesive4
data_clean['Compelling1'] = compelling1
data_clean['Compelling2'] = compelling2
data_clean['Compelling3'] = compelling3
data_clean['Compelling4'] = compelling4

data_clean
# Out:
#    Age  Creative1  Creative2  Creative3  Creative4  Cohesive1  Cohesive2  \
# 0   21          3          2          3          2          2          1
# 1   20          3          1          2          2          3          1
# 2   54          3          2          3          3          3          2
# 3   21          3          4          2          2          2          3
# 4   22          3          2          3          2          2          0
# 5   20          3          2          3          2          2          1
# 6   19          2          2          3          2          2          1
# 7   21          3          1          1          1          3          1
# 8   61          2          2          2          1          2          1
#
#    Cohesive3  Cohesive4  Compelling1  Compelling2  Compelling3  Compelling4
# 0          3          2            2            2            3            2
# 1          2          2            3            1            2            2
# 2          3          2            2            2            3            3
# 3          4          0            3            4            3            1
# 4          1          1            3            1            2            2
# 5          3          2            2            1            4            2
# 6          2          2            1            1            2            1
# 7          1          1            3            0            1            0
# 8          1          1            1            1            1            1

# %% [markdown]
# ## Making plots

# %%
# visualizing histogram of ages
ages= data_clean['Age']
plt.figure(figsize=(10,7))
counts, edges, bars = plt.hist(ages, color='green', alpha=0.8, bins=50)
plt.bar_label(bars)# add count labels
plt.xlabel('Age', fontsize=16)
plt.ylabel('Frequency', fontsize=16)
plt.title('Age distribution for N='+str(len(data_clean))+' respondents', fontsize=18)
plt.show()

# %%
def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{:.1f}%'.format(pct, v=val)
        return my_format

# for pie charts; name is type of thing being rated
def make_4_pie(list1, list2, list3, list4, name):
    figure, axis = plt.subplots(2, 2)

    colors = {'Poor': 'violet',
           'Fair': 'magenta',
           'Adequate': 'Orange',
           'Good': 'Red',
           'Exceptional': 'Cyan'}

    # get unique
    list1_unique = set(list1)
    list1_labels = []
    list1_count = []
    for uni in list1_unique:
        list1_count.append(list1.count(uni))
        list1_labels.append(ratings_key[uni])

    axis[0, 0].pie(list1_count, labels=list1_labels, autopct=autopct_format(list1), colors=[colors[key] for key in list1_labels])
    axis[0,0].set_title('Text 1')

    # get unique
    list2_unique = set(list2)
    list2_labels = []
    list2_count = []
    for uni in list2_unique:
        list2_count.append(list2.count(uni))
        list2_labels.append(ratings_key[uni])

    print(len(list2_labels))

    axis[0, 1].pie(list2_count, labels=list2_labels, autopct=autopct_format(list2), colors=[colors[key] for key in list2_labels])
    axis[0,1].set_title('Text 2')

    # get unique
    list3_unique = set(list3)
    list3_labels = []
    for label in list3_unique:
        list3_labels.append(ratings_key[label])
    list3_count = []
    for uni in list3_unique:
        list3_count.append(list3.count(uni))

    axis[1, 0].pie(list3_count, labels=list3_labels, autopct=autopct_format(list3), colors=[colors[key] for key in list3_labels])
    axis[1,0].set_title('Text 3')

    # get unique
    list4_unique = set(list4)
    list4_labels = []
    for label in list4_unique:
        list4_labels.append(ratings_key[label])
    list4_count = []
    for uni in list4_unique:
        list4_count.append(list4.count(uni))

    axis[1,1].pie(list4_count, labels=list4_labels, autopct=autopct_format(list4), colors=[colors[key] for key in list4_labels])
    axis[1,1].set_title('Text 4')

    figure.suptitle(name+', N='+str(len(list1)), fontsize=18)
    plt.savefig(name+'.jpeg')
    plt.show()

# %%
# function to make plots for all texts
def make_all_plots(data_clean, name_list):
    make_4_pie(data_clean['Creative1'].to_list(), data_clean['Creative2'].to_list(), data_clean['Creative3'].to_list(), data_clean['Creative4'].to_list(), name_list[0])
    make_4_pie(data_clean['Cohesive1'].to_list(), data_clean['Cohesive2'].to_list(), data_clean['Cohesive3'].to_list(), data_clean['Cohesive4'].to_list(), name_list[1])
    make_4_pie(data_clean['Compelling1'].to_list(), data_clean['Compelling2'].to_list(), data_clean['Compelling3'].to_list(), data_clean['Compelling4'].to_list(), name_list[2])

# %%
# get plots for all
make_all_plots(data_clean, ['Creativity', 'Cohesive', 'Compelling'])
# Out:
# 3
# 4
# 4

# %%
# now get restricted
data_clean_restricted = data_clean.loc[data_clean['Age'] < 30]
make_all_plots(data_clean_restricted, ['CreaClip', 'CohClip', 'ComClip'])
# Out:
# 3
# 3
# 4
